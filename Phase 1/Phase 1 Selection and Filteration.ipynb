# %% [markdown]
# # Phase 1: Selection and Filteration
#
# This notebook demonstrates fundamental data operations:
# - **Selection**: Choosing specific columns from datasets
# - **Filteration**: Applying conditions to filter rows
#
# ## Objectives:
# 1. Load customer data
# 2. Select relevant columns
# 3. Apply filtering conditions
# 4. Analyze filtered results

# %%
# Load the customer report data
from pyspark.sql import functions as F

# Read customer data
df_customers = spark.table("workspace.default.customer_report")

print(f"Total records loaded: {df_customers.count():,}")
print(f"\nSchema:")
df_customers.printSchema()
# Out:
# Total records loaded: 454,717
#
# Schema:
# root
#  |-- customer_name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- total_spend: decimal(29,2) (nullable = true)
#  |-- order_count: long (nullable = true)
#  |-- segment: string (nullable = true)
#  |-- first_order_date: date (nullable = true)
#  |-- last_order_date: date (nullable = true)

# %%
# Display sample data
print("Sample of customer data:")
display(df_customers.limit(10))
# Out:
# Sample of customer data:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_name</th><th>city</th><th>total_spend</th><th>order_count</th><th>segment</th><th>first_order_date</th><th>last_order_date</th></tr></thead><tbody><tr><td>Customer#000721180</td><td>xVvi2xMYV7MqiPdC</td><td>7147854.45</td><td>38</td><td>Gold</td><td>1992-01-14</td><td>1998-04-16</td></tr><tr><td>Customer#000382414</td><td>QjI aHlLRIBLeg6HkUjg</td><td>7139342.74</td><td>34</td><td>Gold</td><td>1992-04-30</td><td>1998-04-08</td></tr><tr><td>Customer#000299701</td><td>bQayuLjeavArxOQl</td><td>7128450.99</td><td>43</td><td>Gold</td><td>1992-01-06</td><td>1998-05-23</td></tr><tr><td>Customer#000179275</td><td>t6afpRmxArdPPqqQPSzVRWfpyTxECkQsWaTX</td><td>6887650.62</td><td>35</td><td>Gold</td><td>1992-01-12</td><td>1998-06-24</td></tr><tr><td>Customer#000292987</td><td>CjD</td><td>6833078.18</td><td>38</td><td>Gold</td><td>1992-04-03</td><td>1998-06-21</td></tr><tr><td>Customer#000253099</td><td>fDBy7k7eegbOws6DnsEEyr</td><td>6808439.87</td><td>37</td><td>Gold</td><td>1992-03-02</td><td>1998-06-30</td></tr><tr><td>Customer#000333100</td><td>OB</td><td>6792230.22</td><td>34</td><td>Gold</td><td>1992-01-09</td><td>1998-06-27</td></tr><tr><td>Customer#000370441</td><td>rXocGNGyF2lmjVMV7cK5xlHoGxv3zxEk8FXQg</td><td>6783706.49</td><td>35</td><td>Gold</td><td>1992-01-29</td><td>1998-04-17</td></tr><tr><td>Customer#000318454</td><td></td><td>6769695.98</td><td>40</td><td>Gold</td><td>1992-02-03</td><td>1998-03-28</td></tr><tr><td>Customer#000345637</td><td>xJxwlE1WTg2iDkkCMlu</td><td>6743850.20</td><td>35</td><td>Gold</td><td>1992-06-09</td><td>1998-06-14</td></tr></tbody></table></div>

# %%
# SELECTION: Choose specific columns
selected_columns = df_customers.select(
    "customer_name",
    "city",
    "segment",
    "total_spend",
    "order_count"
)

print("Selected columns: customer_name, city, segment, total_spend, order_count")
display(selected_columns.limit(10))
# Out:
# Selected columns: customer_name, city, segment, total_spend, order_count
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_name</th><th
uB9CVvg</td><td>6570450.24</td><td>30</td><td>Gold</td><td>1992-05-09</td><td>1998-06-02</td></tr><tr><td>Customer#000655378</td><td>YKXDbLgjEJF9j1wHK9cQmN7jaXYMxz</td><td>6567580.53</td><td>32</td><td>Gold</td><td>1992-04-18</td><td>1998-05-27</td></tr><tr><td>Customer#000366799</td><td>0XCXf7ZUrUPiAkfxJGdBeC3</td><td>6552105.70</td><td>34</td><td>Gold</td><td>1992-01-22</td><td>1998-04-12</td></tr><tr><td>Customer#000700384</td><td>i 6pd9bwbW</td><td>6512108.11</td><td>37</td><td>Gold</td><td>1992-06-15</td><td>1998-02-20</td></tr></tbody></table></div>

# %%
# Filter 3: Combined conditions - Gold segment AND high-value
gold_high_value = df_customers.filter(
    (F.col("segment") == "Gold") & 
    (F.col("total_spend") > 5000000)
)

print(f"Gold high-value customers: {gold_high_value.count():,}")
print("\nDistribution by city:")
city_distribution = gold_high_value.groupBy("city").count().orderBy(F.desc("count"))
display(city_distribution.limit(10))
# Out:
# Gold high-value customers: 2,366
#
# Distribution by city:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>count</th></tr></thead><tbody><tr><td></td><td>39</td></tr><tr><td>u</td><td>2</td></tr><tr><td>S</td><td>2</td></tr><tr><td>F</td><td>2</td></tr><tr><td>i</td><td>2</td></tr><tr><td>0</td><td>2</td></tr><tr><td>1</td><td>2</td></tr><tr><td>E</td><td>2</td></tr><tr><td>CjD</td><td>1</td></tr><tr><td>QjI aHlLRIBLeg6HkUjg</td><td>1</td></tr></tbody></table></div>

# %%
# Filter 4: Active customers (order_count >= 30)
active_customers = df_customers.filter(F.col("order_count") >= 30)

print(f"Active customers (>=30 orders): {active_customers.count():,}")
print("\nSegment breakdown:")
segment_breakdown = active_customers.groupBy("segment").agg(
    F.count("*").alias("customer_count"),
    F.sum("total_spend").alias("total_revenue"),
    F.avg("total_spend").alias("avg_spend")
)
display(segment_breakdown)
# Out:
# Active customers (>=30 orders): 4,958
#
# Segment breakdown:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>segment</th><th>customer_count</th><th>total_revenue</th><th>avg_spend</th></tr></thead><tbody><tr><td>Gold</td><td>4958</td><td>23594330761.33</td><td>4758840.411724</td></tr></tbody></table></div>

# %%
# Summary statistics for filtered data
print("=" * 60)
print("PHASE 1 SUMMARY: Selection and Filteration Results")
print("=" * 60)

summary_stats = {
    "Total Customers": df_customers.count(),
    "Gold Customers": gold_customers.count(),
    "High-Value (>$5M)": high_value_customers.count(),
    "Gold + High-Value": gold_high_value.count(),
    "Active (>=30 orders)": active_customers.count()
}

for metric, value in summary_stats.items():
    print(f"{metric:.<50} {value:>10,}")

print("=" * 60)
print("Phase 1 Complete: Data selected and filtered successfully")
# Out:
# ============================================================
# PHASE 1 SUMMARY: Selection and Filteration Results
# ============================================================
# Total Customers...................................    454,717
# Gold Customers....................................    454,716
# High-Value (>$5M).................................      2,366
# Gold + High-Value.................................      2,366
# Active (>=30 orders)..............................      4,958
# ============================================================
# Phase 1 Complete: Data selected and filtered successfully
